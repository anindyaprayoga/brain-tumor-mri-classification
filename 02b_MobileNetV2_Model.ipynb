# %% [markdown]
# # Brain Tumor MRI Classification Project

# %% [markdown]
# ## Project Overview
# This project aims to classify brain tumors from MRI images into four distinct categories: Glioma, Meningioma, No Tumor, and Pituitary. In this first notebook, we establish the data pipeline, perform exploratory data analysis (EDA), and prepare the images for the deep learning training phase.

# %% [markdown]
# ## Extract Preprocessed Data

# %%
import os
import zipfile
import glob

def extract_preprocessed_data():
    zip_candidates = ['/content/preprocessed_data.zip', *glob.glob('/content/*preprocessed*.zip')]
    zip_path = None
    for candidate in zip_candidates:
        if os.path.exists(candidate):
            zip_path = candidate
            break

    if not zip_path:
        print("preprocessed_data.zip not found in /content/")
        return False

    if os.path.exists('/content/preprocessed_data') and os.path.exists('/content/preprocessed_data/config.json'):
        required_files = [
            'X_train.npy', 'X_val.npy', 'X_test.npy',
            'y_train.npy', 'y_val.npy', 'y_test.npy',
            'y_train_cat.npy', 'y_val_cat.npy', 'y_test_cat.npy',
            'config.json'
        ]
        missing = [f for f in required_files if not os.path.exists(f'/content/preprocessed_data/{f}')]
        if not missing:
            print("preprocessed_data folder already exists")
            return True

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall('/content/')

        print(f"Extraction completed: {os.path.basename(zip_path)}")
        return True
    except Exception as e:
        print(f"ERROR: {str(e)}")
        return False

if extract_preprocessed_data():
    for f in sorted(os.listdir('/content/preprocessed_data')):
        print(f"├── {f}")
else:
    print("Cannot proceed without preprocessed data")
# Out:
# Extraction completed: preprocessed_data.zip
# ├── X_test.npy
# ├── X_train.npy
# ├── X_val.npy
# ├── config.json
# ├── y_test.npy
# ├── y_test_cat.npy
# ├── y_train.npy
# ├── y_train_cat.npy
# ├── y_val.npy
# ├── y_val_cat.npy

# %% [markdown]
# ## Environment and Dependencies
# We utilize TensorFlow and Keras for building the neural network, along with NumPy and Pandas
# for data handling. Matplotlib and Seaborn are used for performance visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import time
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (ModelCheckpoint,ReduceLROnPlateau,LearningRateScheduler)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
np.random.seed(42)
tf.random.set_seed(42)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
print(f"TensorFlow Version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Data Pipeline
# The dataset consists of preprocessed MRI scans stored as NumPy arrays. We define paths for
# loading data and saving training artifacts.

# %%
DATA_PATH = '/content/preprocessed_data'
OUTPUT_PATH = '/content/training_results'
os.makedirs(OUTPUT_PATH, exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/models', exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/histories', exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/plots', exist_ok=True)
X_train = np.load(f'{DATA_PATH}/X_train.npy')
X_val = np.load(f'{DATA_PATH}/X_val.npy')
X_test = np.load(f'{DATA_PATH}/X_test.npy')
y_train_cat = np.load(f'{DATA_PATH}/y_train_cat.npy')
y_val_cat = np.load(f'{DATA_PATH}/y_val_cat.npy')
y_test_cat = np.load(f'{DATA_PATH}/y_test_cat.npy')
with open(f'{DATA_PATH}/config.json', 'r') as f:
    config = json.load(f)

# %% [markdown]
# ## Data Augmentation Strategy
#
# To improve model generalization and mitigate overfitting, we implement a moderate augmentation strategy that includes rotations, shifts, and flips. Vertical flipping is deemed safe for MRI
# brain scans.

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %% [markdown]
# ## Model Architecture
#
# This time we use MobileNetV2 as transfer learning model which loaded with imagenet weight. we freeze the base model layer and train the top layer of the model. Each block after transfer learning block is followed by Batch Normalization and Dropout.

# %%
def build_mobilenetv2(input_shape=(224, 224, 3), num_classes=4):
    # Load MobileNetV2 base model
    base_model = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    # Freeze base model layers
    base_model.trainable = False

    # Build model with MobileNetV2 base
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dropout(0.55),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.55),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.55),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

# %%
model = build_mobilenetv2(
    input_shape=X_train.shape[1:],
    num_classes=config['num_classes']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## Training Process
#
# The model is trained for 100 epochs using the Adam optimizer. We monitor validation accuracy
# to save the best weights and reduce the learning rate when the loss plateaus.

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

# %%
callbacks = [
    ModelCheckpoint(filepath=f'{OUTPUT_PATH}/models/best_model.h5', monitor='val_accuracy', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7)
]

# %%
history = model.fit(
    train_datagen.flow(X_train, y_train_cat, batch_size=32),
    epochs=100,
    validation_data=(X_val, y_val_cat),
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.5701 - loss: 1.3596 - precision: 0.5941 - recall: 0.5436
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 110s 568ms/step - accuracy: 0.5708 - loss: 1.3574 - precision: 0.5948 - recall: 0.5443 - val_accuracy: 0.7713 - val_loss: 0.5924 - val_precision: 0.7917 - val_recall: 0.7585 - learning_rate: 0.0010
# Epoch 2/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7555 - loss: 0.6921 - precision: 0.7764 - recall: 0.7393
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.7557 - loss: 0.6917 - precision: 0.7765 - recall: 0.7394 - val_accuracy: 0.8378 - val_loss: 0.4249 - val_precision: 0.8537 - val_recall: 0.8238 - learning_rate: 0.0010
# Epoch 3/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7818 - loss: 0.6168 - precision: 0.8021 - recall: 0.7635
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.7819 - loss: 0.6165 - precision: 0.8022 - recall: 0.7635 - val_accuracy: 0.8390 - val_loss: 0.4209 - val_precision: 0.8556 - val_recall: 0.8226 - learning_rate: 0.0010
# Epoch 4/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7981 - loss: 0.5194 - precision: 0.8195 - recall: 0.7779
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.7982 - loss: 0.5194 - precision: 0.8195 - recall: 0.7780 - val_accuracy: 0.8623 - val_loss: 0.3513 - val_precision: 0.8854 - val_recall: 0.8471 - learning_rate: 0.0010
# Epoch 5/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 365ms/step - accuracy: 0.8373 - loss: 0.4493 - precision: 0.8532 - recall: 0.8155 - val_accuracy: 0.8541 - val_loss: 0.3549 - val_precision: 0.8811 - val_recall: 0.8390 - learning_rate: 0.0010
# Epoch 6/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8290 - loss: 0.4379 - precision: 0.8504 - recall: 0.8080
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 363ms/step - accuracy: 0.8290 - loss: 0.4379 - precision: 0.8504 - recall: 0.8080 - val_accuracy: 0.8681 - val_loss: 0.3544 - val_precision: 0.8819 - val_recall: 0.8448 - learning_rate: 0.0010
# Epoch 7/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8209 - loss: 0.4515 - precision: 0.8433 - recall: 0.8005
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 363ms/step - accuracy: 0.8210 - loss: 0.4514 - precision: 0.8434 - recall: 0.8005 - val_accuracy: 0.8775 - val_loss: 0.3237 - val_precision: 0.8956 - val_recall: 0.8611 - learning_rate: 0.0010
# Epoch 8/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 364ms/step - accuracy: 0.8425 - loss: 0.4157 - precision: 0.8617 - recall: 0.8169 - val_accuracy: 0.8716 - val_loss: 0.3280 - val_precision: 0.8938 - val_recall: 0.8541 - learning_rate: 0.0010
# Epoch 9/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8427 - loss: 0.4141 - precision: 0.8589 - recall: 0.8204 - val_accuracy: 0.8658 - val_loss: 0.3307 - val_precision: 0.8873 - val_recall: 0.8541 - learning_rate: 0.0010
# Epoch 10/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8526 - loss: 0.3931 - precision: 0.8728 - recall: 0.8308
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 365ms/step - accuracy: 0.8525 - loss: 0.3932 - precision: 0.8728 - recall: 0.8308 - val_accuracy: 0.8868 - val_loss: 0.2916 - val_precision: 0.8978 - val_recall: 0.8716 - learning_rate: 0.0010
# Epoch 11/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.8473 - loss: 0.3952 - precision: 0.8637 - recall: 0.8318 - val_accuracy: 0.8786 - val_loss: 0.3169 - val_precision: 0.8936 - val_recall: 0.8623 - learning_rate: 0.0010
# Epoch 12/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 364ms/step - accuracy: 0.8581 - loss: 0.3697 - precision: 0.8738 - recall: 0.8419 - val_accuracy: 0.8868 - val_loss: 0.3029 - val_precision: 0.8971 - val_recall: 0.8751 - learning_rate: 0.0010
# Epoch 13/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8526 - loss: 0.3702 - precision: 0.8677 - recall: 0.8336 - val_accuracy: 0.8728 - val_loss: 0.3137 - val_precision: 0.8875 - val_recall: 0.8565 - learning_rate: 0.0010
# Epoch 14/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8629 - loss: 0.3679 - precision: 0.8796 - recall: 0.8460 - val_accuracy: 0.8833 - val_loss: 0.2923 - val_precision: 0.8988 - val_recall: 0.8705 - learning_rate: 0.0010
# Epoch 15/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8580 - loss: 0.3537 - precision: 0.8732 - recall: 0.8396 - val_accuracy: 0.8751 - val_loss: 0.2944 - val_precision: 0.8866 - val_recall: 0.8576 - learning_rate: 0.0010
# Epoch 16/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8527 - loss: 0.3611 - precision: 0.8613 - recall: 0.8354 - val_accuracy: 0.8786 - val_loss: 0.2859 - val_precision: 0.8990 - val_recall: 0.8623 - learning_rate: 0.0010
# Epoch 17/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.8581 - loss: 0.3586 - precision: 0.8713 - recall: 0.8428 - val_accuracy: 0.8775 - val_loss: 0.3042 - val_precision: 0.8947 - val_recall: 0.8623 - learning_rate: 0.0010
# Epoch 18/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8549 - loss: 0.3757 - precision: 0.8716 - recall: 0.8384 - val_accuracy: 0.8775 - val_loss: 0.3122 - val_precision: 0.8938 - val_recall: 0.8646 - learning_rate: 0.0010
# Epoch 19/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8588 - loss: 0.3637 - precision: 0.8735 - recall: 0.8482 - val_accuracy: 0.8751 - val_loss: 0.3187 - val_precision: 0.8878 - val_recall: 0.8681 - learning_rate: 0.0010
# Epoch 20/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - accuracy: 0.8668 - loss: 0.3564 - precision: 0.8806 - recall: 0.8545 - val_accuracy: 0.8565 - val_loss: 0.3372 - val_precision: 0.8684 - val_recall: 0.8471 - learning_rate: 0.0010
# Epoch 21/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - accuracy: 0.8652 - loss: 0.3601 - precision: 0.8779 - recall: 0.8471 - val_accuracy: 0.8658 - val_loss: 0.3159 - val_precision: 0.8818 - val_recall: 0.8530 - learning_rate: 0.0010
# Epoch 22/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 374ms/step - accuracy: 0.8638 - loss: 0.3611 - precision: 0.8775 - recall: 0.8490 - val_accuracy: 0.8868 - val_loss: 0.2765 - val_precision: 0.9048 - val_recall: 0.8763 - learning_rate: 0.0010
# Epoch 23/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8671 - loss: 0.3516 - precision: 0.8788 - recall: 0.8538
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.8671 - loss: 0.3516 - precision: 0.8788 - recall: 0.8538 - val_accuracy: 0.8880 - val_loss: 0.2752 - val_precision: 0.9017 - val_recall: 0.8775 - learning_rate: 0.0010
# Epoch 24/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 382ms/step - accuracy: 0.8637 - loss: 0.3405 - precision: 0.8768 - recall: 0.8488 - val_accuracy: 0.8786 - val_loss: 0.2893 - val_precision: 0.8940 - val_recall: 0.8658 - learning_rate: 0.0010
# Epoch 25/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8606 - loss: 0.3668 - precision: 0.8721 - recall: 0.8421
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 376ms/step - accuracy: 0.8607 - loss: 0.3667 - precision: 0.8721 - recall: 0.8422 - val_accuracy: 0.8973 - val_loss: 0.2496 - val_precision: 0.9088 - val_recall: 0.8833 - learning_rate: 0.0010
# Epoch 26/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 379ms/step - accuracy: 0.8736 - loss: 0.3365 - precision: 0.8816 - recall: 0.8602 - val_accuracy: 0.8915 - val_loss: 0.2697 - val_precision: 0.9042 - val_recall: 0.8810 - learning_rate: 0.0010
# Epoch 27/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8641 - loss: 0.3634 - precision: 0.8789 - recall: 0.8499 - val_accuracy: 0.8961 - val_loss: 0.2725 - val_precision: 0.9012 - val_recall: 0.8833 - learning_rate: 0.0010
# Epoch 28/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.8904 - loss: 0.3121 - precision: 0.9001 - recall: 0.8759 - val_accuracy: 0.8915 - val_loss: 0.2929 - val_precision: 0.9020 - val_recall: 0.8810 - learning_rate: 0.0010
# Epoch 29/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 378ms/step - accuracy: 0.8743 - loss: 0.3347 - precision: 0.8832 - recall: 0.8624 - val_accuracy: 0.8775 - val_loss: 0.3223 - val_precision: 0.8853 - val_recall: 0.8646 - learning_rate: 0.0010
# Epoch 30/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8781 - loss: 0.3276 - precision: 0.8888 - recall: 0.8666
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8780 - loss: 0.3276 - precision: 0.8888 - recall: 0.8665 - val_accuracy: 0.9032 - val_loss: 0.2510 - val_precision: 0.9127 - val_recall: 0.8903 - learning_rate: 0.0010
# Epoch 31/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 382ms/step - accuracy: 0.8799 - loss: 0.3226 - precision: 0.8932 - recall: 0.8706 - val_accuracy: 0.8868 - val_loss: 0.2840 - val_precision: 0.9016 - val_recall: 0.8763 - learning_rate: 0.0010
# Epoch 32/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8702 - loss: 0.3424 - precision: 0.8798 - recall: 0.8564 - val_accuracy: 0.8996 - val_loss: 0.2702 - val_precision: 0.9143 - val_recall: 0.8833 - learning_rate: 0.0010
# Epoch 33/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8781 - loss: 0.3103 - precision: 0.8890 - recall: 0.8669 - val_accuracy: 0.8950 - val_loss: 0.2775 - val_precision: 0.9068 - val_recall: 0.8856 - learning_rate: 5.0000e-04
# Epoch 34/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.8919 - loss: 0.3030 - precision: 0.9046 - recall: 0.8799 - val_accuracy: 0.9032 - val_loss: 0.2732 - val_precision: 0.9123 - val_recall: 0.8856 - learning_rate: 5.0000e-04
# Epoch 35/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 376ms/step - accuracy: 0.8799 - loss: 0.3078 - precision: 0.8924 - recall: 0.8700 - val_accuracy: 0.8891 - val_loss: 0.2959 - val_precision: 0.9002 - val_recall: 0.8740 - learning_rate: 5.0000e-04
# Epoch 36/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8812 - loss: 0.3284 - precision: 0.8935 - recall: 0.8651 - val_accuracy: 0.8810 - val_loss: 0.2997 - val_precision: 0.8920 - val_recall: 0.8670 - learning_rate: 5.0000e-04
# Epoch 37/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8777 - loss: 0.3351 - precision: 0.8878 - recall: 0.8643 - val_accuracy: 0.8880 - val_loss: 0.2910 - val_precision: 0.8911 - val_recall: 0.8693 - learning_rate: 5.0000e-04
# Epoch 38/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8887 - loss: 0.2994 - precision: 0.8988 - recall: 0.8724 - val_accuracy: 0.8856 - val_loss: 0.2888 - val_precision: 0.8921 - val_recall: 0.8775 - learning_rate: 5.0000e-04
# Epoch 39/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8873 - loss: 0.2999 - precision: 0.8984 - recall: 0.8791 - val_accuracy: 0.9020 - val_loss: 0.2648 - val_precision: 0.9073 - val_recall: 0.8903 - learning_rate: 5.0000e-04
# Epoch 40/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 379ms/step - accuracy: 0.8849 - loss: 0.3051 - precision: 0.8970 - recall: 0.8755 - val_accuracy: 0.8985 - val_loss: 0.2679 - val_precision: 0.9035 - val_recall: 0.8845 - learning_rate: 2.5000e-04
# Epoch 41/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 379ms/step - accuracy: 0.8976 - loss: 0.2923 - precision: 0.9034 - recall: 0.8887 - val_accuracy: 0.9008 - val_loss: 0.2637 - val_precision: 0.9117 - val_recall: 0.8915 - learning_rate: 2.5000e-04
# Epoch 42/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 377ms/step - accuracy: 0.8911 - loss: 0.2937 - precision: 0.9006 - recall: 0.8799 - val_accuracy: 0.9020 - val_loss: 0.2545 - val_precision: 0.9163 - val_recall: 0.8938 - learning_rate: 2.5000e-04
# Epoch 43/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8888 - loss: 0.3073 - precision: 0.8989 - recall: 0.8787 - val_accuracy: 0.8996 - val_loss: 0.2581 - val_precision: 0.9094 - val_recall: 0.8903 - learning_rate: 2.5000e-04
# Epoch 44/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - accuracy: 0.8910 - loss: 0.2869 - precision: 0.9008 - recall: 0.8817 - val_accuracy: 0.9020 - val_loss: 0.2572 - val_precision: 0.9118 - val_recall: 0.8926 - learning_rate: 2.5000e-04
# Epoch 45/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - accuracy: 0.8907 - loss: 0.2856 - precision: 0.8987 - recall: 0.8808 - val_accuracy: 0.8973 - val_loss: 0.2719 - val_precision: 0.9079 - val_recall: 0.8856 - learning_rate: 2.5000e-04
# Epoch 46/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8987 - loss: 0.2825 - precision: 0.9109 - recall: 0.8900
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8987 - loss: 0.2825 - precision: 0.9108 - recall: 0.8900 - val_accuracy: 0.9078 - val_loss: 0.2591 - val_precision: 0.9142 - val_recall: 0.8950 - learning_rate: 2.5000e-04
# Epoch 47/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - accuracy: 0.8996 - loss: 0.2821 - precision: 0.9059 - recall: 0.8871 - val_accuracy: 0.9067 - val_loss: 0.2560 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 1.2500e-04
# Epoch 48/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8919 - loss: 0.2834 - precision: 0.9005 - recall: 0.8802 - val_accuracy: 0.9055 - val_loss: 0.2510 - val_precision: 0.9155 - val_recall: 0.8973 - learning_rate: 1.2500e-04
# Epoch 49/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 379ms/step - accuracy: 0.8809 - loss: 0.2990 - precision: 0.8885 - recall: 0.8692 - val_accuracy: 0.9055 - val_loss: 0.2506 - val_precision: 0.9142 - val_recall: 0.8950 - learning_rate: 1.2500e-04
# Epoch 50/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 380ms/step - accuracy: 0.8879 - loss: 0.2725 - precision: 0.8972 - recall: 0.8809 - val_accuracy: 0.9067 - val_loss: 0.2502 - val_precision: 0.9165 - val_recall: 0.8961 - learning_rate: 1.2500e-04
# Epoch 51/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 376ms/step - accuracy: 0.9029 - loss: 0.2564 - precision: 0.9107 - recall: 0.8928 - val_accuracy: 0.9055 - val_loss: 0.2558 - val_precision: 0.9132 - val_recall: 0.8961 - learning_rate: 1.2500e-04
# Epoch 52/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 376ms/step - accuracy: 0.8875 - loss: 0.2877 - precision: 0.8953 - recall: 0.8773 - val_accuracy: 0.9032 - val_loss: 0.2624 - val_precision: 0.9129 - val_recall: 0.8926 - learning_rate: 1.2500e-04
# Epoch 53/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 377ms/step - accuracy: 0.8914 - loss: 0.2839 - precision: 0.8988 - recall: 0.8858 - val_accuracy: 0.9078 - val_loss: 0.2513 - val_precision: 0.9146 - val_recall: 0.8996 - learning_rate: 1.2500e-04
# Epoch 54/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 378ms/step - accuracy: 0.8951 - loss: 0.2828 - precision: 0.9041 - recall: 0.8839 - val_accuracy: 0.9078 - val_loss: 0.2508 - val_precision: 0.9146 - val_recall: 0.8996 - learning_rate: 6.2500e-05
# Epoch 55/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.8924 - loss: 0.2908 - precision: 0.9025 - recall: 0.8820 - val_accuracy: 0.9067 - val_loss: 0.2523 - val_precision: 0.9152 - val_recall: 0.8938 - learning_rate: 6.2500e-05
# Epoch 56/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.8877 - loss: 0.2872 - precision: 0.8954 - recall: 0.8783 - val_accuracy: 0.9055 - val_loss: 0.2519 - val_precision: 0.9163 - val_recall: 0.8938 - learning_rate: 6.2500e-05
# Epoch 57/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 382ms/step - accuracy: 0.8958 - loss: 0.2777 - precision: 0.9036 - recall: 0.8845 - val_accuracy: 0.9078 - val_loss: 0.2492 - val_precision: 0.9154 - val_recall: 0.8961 - learning_rate: 6.2500e-05
# Epoch 58/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 392ms/step - accuracy: 0.8925 - loss: 0.2727 - precision: 0.9010 - recall: 0.8846 - val_accuracy: 0.9067 - val_loss: 0.2489 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 6.2500e-05
# Epoch 59/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8885 - loss: 0.2783 - precision: 0.8975 - recall: 0.8826 - val_accuracy: 0.9078 - val_loss: 0.2505 - val_precision: 0.9146 - val_recall: 0.8996 - learning_rate: 6.2500e-05
# Epoch 60/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 84s 385ms/step - accuracy: 0.9002 - loss: 0.2639 - precision: 0.9092 - recall: 0.8893 - val_accuracy: 0.9043 - val_loss: 0.2565 - val_precision: 0.9117 - val_recall: 0.8915 - learning_rate: 6.2500e-05
# Epoch 61/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.8963 - loss: 0.2639 - precision: 0.9044 - recall: 0.8852 - val_accuracy: 0.9032 - val_loss: 0.2562 - val_precision: 0.9140 - val_recall: 0.8926 - learning_rate: 6.2500e-05
# Epoch 62/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 82s 373ms/step - accuracy: 0.8919 - loss: 0.2748 - precision: 0.9023 - recall: 0.8855 - val_accuracy: 0.9043 - val_loss: 0.2548 - val_precision: 0.9122 - val_recall: 0.8973 - learning_rate: 6.2500e-05
# Epoch 63/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8962 - loss: 0.2724 - precision: 0.9052 - recall: 0.8890 - val_accuracy: 0.9055 - val_loss: 0.2528 - val_precision: 0.9127 - val_recall: 0.8903 - learning_rate: 6.2500e-05
# Epoch 64/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8802 - loss: 0.3095 - precision: 0.8880 - recall: 0.8696 - val_accuracy: 0.9032 - val_loss: 0.2558 - val_precision: 0.9128 - val_recall: 0.8915 - learning_rate: 6.2500e-05
# Epoch 65/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 384ms/step - accuracy: 0.9007 - loss: 0.2707 - precision: 0.9083 - recall: 0.8877 - val_accuracy: 0.9020 - val_loss: 0.2580 - val_precision: 0.9140 - val_recall: 0.8926 - learning_rate: 6.2500e-05
# Epoch 66/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 380ms/step - accuracy: 0.8934 - loss: 0.2899 - precision: 0.9024 - recall: 0.8861 - val_accuracy: 0.9043 - val_loss: 0.2535 - val_precision: 0.9154 - val_recall: 0.8961 - learning_rate: 3.1250e-05
# Epoch 67/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 374ms/step - accuracy: 0.9014 - loss: 0.2469 - precision: 0.9092 - recall: 0.8922 - val_accuracy: 0.9032 - val_loss: 0.2559 - val_precision: 0.9140 - val_recall: 0.8926 - learning_rate: 3.1250e-05
# Epoch 68/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 375ms/step - accuracy: 0.9005 - loss: 0.2589 - precision: 0.9076 - recall: 0.8899 - val_accuracy: 0.9078 - val_loss: 0.2497 - val_precision: 0.9168 - val_recall: 0.8996 - learning_rate: 3.1250e-05
# Epoch 69/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 383ms/step - accuracy: 0.8915 - loss: 0.2721 - precision: 0.9025 - recall: 0.8829 - val_accuracy: 0.9043 - val_loss: 0.2533 - val_precision: 0.9155 - val_recall: 0.8973 - learning_rate: 3.1250e-05
# Epoch 70/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 371ms/step - accuracy: 0.8890 - loss: 0.2832 - precision: 0.8947 - recall: 0.8786 - val_accuracy: 0.9055 - val_loss: 0.2511 - val_precision: 0.9134 - val_recall: 0.8985 - learning_rate: 3.1250e-05
# Epoch 71/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 364ms/step - accuracy: 0.8966 - loss: 0.2858 - precision: 0.9048 - recall: 0.8856 - val_accuracy: 0.9032 - val_loss: 0.2537 - val_precision: 0.9142 - val_recall: 0.8950 - learning_rate: 3.1250e-05
# Epoch 72/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8905 - loss: 0.2705 - precision: 0.9021 - recall: 0.8836 - val_accuracy: 0.9067 - val_loss: 0.2523 - val_precision: 0.9143 - val_recall: 0.8961 - learning_rate: 3.1250e-05
# Epoch 73/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.8958 - loss: 0.2700 - precision: 0.9003 - recall: 0.8844 - val_accuracy: 0.9055 - val_loss: 0.2527 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 1.5625e-05
# Epoch 74/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 403ms/step - accuracy: 0.9031 - loss: 0.2552 - precision: 0.9127 - recall: 0.8923 - val_accuracy: 0.9055 - val_loss: 0.2500 - val_precision: 0.9167 - val_recall: 0.8985 - learning_rate: 1.5625e-05
# Epoch 75/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 378ms/step - accuracy: 0.8923 - loss: 0.2817 - precision: 0.9001 - recall: 0.8827 - val_accuracy: 0.9043 - val_loss: 0.2499 - val_precision: 0.9145 - val_recall: 0.8985 - learning_rate: 1.5625e-05
# Epoch 76/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 58s 382ms/step - accuracy: 0.8910 - loss: 0.2713 - precision: 0.9009 - recall: 0.8836 - val_accuracy: 0.9067 - val_loss: 0.2512 - val_precision: 0.9169 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 77/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.8875 - loss: 0.2934 - precision: 0.8980 - recall: 0.8785 - val_accuracy: 0.9067 - val_loss: 0.2487 - val_precision: 0.9157 - val_recall: 0.8996 - learning_rate: 1.5625e-05
# Epoch 78/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 374ms/step - accuracy: 0.9025 - loss: 0.2642 - precision: 0.9103 - recall: 0.8888 - val_accuracy: 0.9067 - val_loss: 0.2489 - val_precision: 0.9157 - val_recall: 0.8996 - learning_rate: 1.5625e-05
# Epoch 79/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - accuracy: 0.8964 - loss: 0.2765 - precision: 0.9046 - recall: 0.8907 - val_accuracy: 0.9067 - val_loss: 0.2453 - val_precision: 0.9181 - val_recall: 0.9032 - learning_rate: 1.5625e-05
# Epoch 80/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 364ms/step - accuracy: 0.8881 - loss: 0.2806 - precision: 0.8988 - recall: 0.8791 - val_accuracy: 0.9055 - val_loss: 0.2486 - val_precision: 0.9147 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 81/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8969 - loss: 0.2698 - precision: 0.9051 - recall: 0.8902 - val_accuracy: 0.9078 - val_loss: 0.2449 - val_precision: 0.9180 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 82/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 374ms/step - accuracy: 0.8983 - loss: 0.2753 - precision: 0.9085 - recall: 0.8881 - val_accuracy: 0.9067 - val_loss: 0.2461 - val_precision: 0.9169 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 83/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 376ms/step - accuracy: 0.8932 - loss: 0.2547 - precision: 0.9056 - recall: 0.8858 - val_accuracy: 0.9055 - val_loss: 0.2483 - val_precision: 0.9169 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 84/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.9009 - loss: 0.2533 - precision: 0.9096 - recall: 0.8932 - val_accuracy: 0.9078 - val_loss: 0.2460 - val_precision: 0.9170 - val_recall: 0.9020 - learning_rate: 1.5625e-05
# Epoch 85/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 364ms/step - accuracy: 0.8896 - loss: 0.2838 - precision: 0.8967 - recall: 0.8822 - val_accuracy: 0.9067 - val_loss: 0.2467 - val_precision: 0.9170 - val_recall: 0.9020 - learning_rate: 1.5625e-05
# Epoch 86/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 374ms/step - accuracy: 0.8971 - loss: 0.2668 - precision: 0.9027 - recall: 0.8884 - val_accuracy: 0.9078 - val_loss: 0.2466 - val_precision: 0.9170 - val_recall: 0.9020 - learning_rate: 1.5625e-05
# Epoch 87/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.8889 - loss: 0.2786 - precision: 0.9019 - recall: 0.8802 - val_accuracy: 0.9067 - val_loss: 0.2496 - val_precision: 0.9147 - val_recall: 0.9008 - learning_rate: 1.5625e-05
# Epoch 88/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 59s 387ms/step - accuracy: 0.8956 - loss: 0.2799 - precision: 0.9040 - recall: 0.8859 - val_accuracy: 0.9055 - val_loss: 0.2479 - val_precision: 0.9157 - val_recall: 0.8996 - learning_rate: 1.5625e-05
# Epoch 89/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 373ms/step - accuracy: 0.8966 - loss: 0.2600 - precision: 0.9049 - recall: 0.8899 - val_accuracy: 0.9055 - val_loss: 0.2509 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 7.8125e-06
# Epoch 90/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 363ms/step - accuracy: 0.9020 - loss: 0.2624 - precision: 0.9105 - recall: 0.8925 - val_accuracy: 0.9043 - val_loss: 0.2488 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 7.8125e-06
# Epoch 91/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 54s 356ms/step - accuracy: 0.8981 - loss: 0.2748 - precision: 0.9065 - recall: 0.8837 - val_accuracy: 0.9043 - val_loss: 0.2483 - val_precision: 0.9132 - val_recall: 0.8961 - learning_rate: 7.8125e-06
# Epoch 92/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 372ms/step - accuracy: 0.9012 - loss: 0.2594 - precision: 0.9090 - recall: 0.8928 - val_accuracy: 0.9078 - val_loss: 0.2467 - val_precision: 0.9167 - val_recall: 0.8985 - learning_rate: 7.8125e-06
# Epoch 93/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 55s 363ms/step - accuracy: 0.9012 - loss: 0.2656 - precision: 0.9097 - recall: 0.8881 - val_accuracy: 0.9043 - val_loss: 0.2504 - val_precision: 0.9132 - val_recall: 0.8961 - learning_rate: 7.8125e-06
# Epoch 94/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8959 - loss: 0.2771 - precision: 0.9086 - recall: 0.8886 - val_accuracy: 0.9043 - val_loss: 0.2504 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 7.8125e-06
# Epoch 95/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8997 - loss: 0.2673 - precision: 0.9069 - recall: 0.8907 - val_accuracy: 0.9055 - val_loss: 0.2508 - val_precision: 0.9135 - val_recall: 0.8996 - learning_rate: 7.8125e-06
# Epoch 96/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - accuracy: 0.8860 - loss: 0.2931 - precision: 0.8927 - recall: 0.8754 - val_accuracy: 0.9043 - val_loss: 0.2527 - val_precision: 0.9136 - val_recall: 0.9008 - learning_rate: 3.9063e-06
# Epoch 97/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - accuracy: 0.8974 - loss: 0.2677 - precision: 0.9085 - recall: 0.8910 - val_accuracy: 0.9043 - val_loss: 0.2504 - val_precision: 0.9133 - val_recall: 0.8973 - learning_rate: 3.9063e-06
# Epoch 98/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - accuracy: 0.8987 - loss: 0.2801 - precision: 0.9063 - recall: 0.8872 - val_accuracy: 0.9032 - val_loss: 0.2521 - val_precision: 0.9112 - val_recall: 0.8985 - learning_rate: 3.9063e-06
# Epoch 99/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 378ms/step - accuracy: 0.8969 - loss: 0.2743 - precision: 0.9035 - recall: 0.8890 - val_accuracy: 0.9055 - val_loss: 0.2495 - val_precision: 0.9156 - val_recall: 0.8985 - learning_rate: 3.9063e-06
# Epoch 100/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 57s 371ms/step - accuracy: 0.8917 - loss: 0.2916 - precision: 0.9014 - recall: 0.8818 - val_accuracy: 0.9043 - val_loss: 0.2478 - val_precision: 0.9144 - val_recall: 0.8973 - learning_rate: 3.9063e-06

# %%
MODEL_NAME = 'mobilenetv2'

# %%
history_path = f'{OUTPUT_PATH}/histories/{MODEL_NAME}_history.npy'
np.save(history_path, history.history)

# %%
final_model_path = f'{OUTPUT_PATH}/models/{MODEL_NAME}_final.h5'
model.save(final_model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
best_model = keras.models.load_model(f'{OUTPUT_PATH}/models/{MODEL_NAME}_final.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Test Time Augmentation (TTA)
#
# TTA is utilized during the inference phase. By generating 10 augmented versions of each test
# image and averaging the predictions, we significantly increase the robustness of the final classification.

# %%
def predict_with_tta(model, X, n_augmentations=10):
    predictions = []
    preds = model.predict(X, verbose=0)
    predictions.append(preds)
    tta_gen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True
    )
    for i in range(n_augmentations):
        aug_iterator = tta_gen.flow(X, batch_size=len(X), shuffle=False)
        X_aug = next(iter(aug_iterator))
        preds_aug = model.predict(X_aug, verbose=0)
        predictions.append(preds_aug)
    return np.mean(predictions, axis=0)

test_preds_tta = predict_with_tta(best_model, X_test, n_augmentations=10)
test_acc_tta = np.mean(np.argmax(test_preds_tta, axis=1) == np.argmax(y_test_cat, axis=1))

print(f"\nTTA completed!")

# EVALUATION

print("\n")
print("EVALUATION")

# Validation
val_results = best_model.evaluate(X_val, y_val_cat, verbose=0)
print(f"\nValidation Results (Best Model):")
print(f"Loss: {val_results[0]:.4f}")
print(f"Accuracy: {val_results[1]*100:.2f}%")
print(f"Precision: {val_results[2]:.4f}")
print(f"Recall: {val_results[3]:.4f}")

# Test (standard)
test_results = best_model.evaluate(X_test, y_test_cat, verbose=0)
print(f"\nTest Results (Standard):")
print(f"Loss: {test_results[0]:.4f}")
print(f"Accuracy: {test_results[1]*100:.2f}%")
print(f"Precision: {test_results[2]:.4f}")
print(f"Recall: {test_results[3]:.4f}")

# Test (with TTA)
print(f"\nTest Results (With TTA):")
print(f"Accuracy: {test_acc_tta*100:.2f}%")

print("\nSUMMARY:")
print(f"Baseline Test Acc: 93.82%")
print(f"Test Acc (Standard): {test_results[1]*100:.2f}%")
print(f"Test Acc (TTA): {test_acc_tta*100:.2f}%")
# Out:
# TTA completed!
#
#
# EVALUATION
#
# Validation Results (Best Model):
# Loss: 0.2478
# Accuracy: 90.43%
# Precision: 0.9144
# Recall: 0.8973
#
# Test Results (Standard):
# Loss: 0.2768
# Accuracy: 89.55%
# Precision: 0.9014
# Recall: 0.8856
#
# Test Results (With TTA):
# Accuracy: 93.14%
#
# SUMMARY:
# Baseline Test Acc: 93.82%
# Test Acc (Standard): 89.55%
# Test Acc (TTA): 93.14%

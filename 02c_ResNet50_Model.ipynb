# %% [markdown]
# # Brain Tumor MRI Classification Project

# %% [markdown]
# ## Project Overview
# This project aims to classify brain tumors from MRI images into four distinct categories: Glioma, Meningioma, No Tumor, and Pituitary. In this first notebook, we establish the data pipeline, perform exploratory data analysis (EDA), and prepare the images for the deep learning training phase.

# %% [markdown]
# ## Extract Preprocessed Data

# %%
import os
import zipfile
import glob

def extract_preprocessed_data():
    zip_candidates = ['/content/preprocessed_data.zip', *glob.glob('/content/*preprocessed*.zip')]
    zip_path = None
    for candidate in zip_candidates:
        if os.path.exists(candidate):
            zip_path = candidate
            break

    if not zip_path:
        print("preprocessed_data.zip not found in /content/")
        return False

    if os.path.exists('/content/preprocessed_data') and os.path.exists('/content/preprocessed_data/config.json'):
        required_files = [
            'X_train.npy', 'X_val.npy', 'X_test.npy',
            'y_train.npy', 'y_val.npy', 'y_test.npy',
            'y_train_cat.npy', 'y_val_cat.npy', 'y_test_cat.npy',
            'config.json'
        ]
        missing = [f for f in required_files if not os.path.exists(f'/content/preprocessed_data/{f}')]
        if not missing:
            print("preprocessed_data folder already exists")
            return True

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall('/content/')

        print(f"Extraction completed: {os.path.basename(zip_path)}")
        return True
    except Exception as e:
        print(f"ERROR: {str(e)}")
        return False

if extract_preprocessed_data():
    for f in sorted(os.listdir('/content/preprocessed_data')):
        print(f"├── {f}")
else:
    print("Cannot proceed without preprocessed data")
# Out:
# Extraction completed: preprocessed_data.zip
# ├── X_test.npy
# ├── X_train.npy
# ├── X_val.npy
# ├── config.json
# ├── y_test.npy
# ├── y_test_cat.npy
# ├── y_train.npy
# ├── y_train_cat.npy
# ├── y_val.npy
# ├── y_val_cat.npy

# %% [markdown]
# ## Environment and Dependencies
# We utilize TensorFlow and Keras for building the neural network, along with NumPy and Pandas
# for data handling. Matplotlib and Seaborn are used for performance visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import time
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (ModelCheckpoint,ReduceLROnPlateau,LearningRateScheduler)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
np.random.seed(42)
tf.random.set_seed(42)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
print(f"TensorFlow Version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Data Pipeline
# The dataset consists of preprocessed MRI scans stored as NumPy arrays. We define paths for
# loading data and saving training artifacts.

# %%
DATA_PATH = '/content/preprocessed_data'
OUTPUT_PATH = '/content/training_results'
os.makedirs(OUTPUT_PATH, exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/models', exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/histories', exist_ok=True)
os.makedirs(f'{OUTPUT_PATH}/plots', exist_ok=True)
X_train = np.load(f'{DATA_PATH}/X_train.npy')
X_val = np.load(f'{DATA_PATH}/X_val.npy')
X_test = np.load(f'{DATA_PATH}/X_test.npy')
y_train_cat = np.load(f'{DATA_PATH}/y_train_cat.npy')
y_val_cat = np.load(f'{DATA_PATH}/y_val_cat.npy')
y_test_cat = np.load(f'{DATA_PATH}/y_test_cat.npy')
with open(f'{DATA_PATH}/config.json', 'r') as f:
    config = json.load(f)

# %% [markdown]
# ## Data Augmentation Strategy
#
# To improve model generalization and mitigate overfitting, we implement a moderate augmentation strategy that includes rotations, shifts, and flips. Vertical flipping is deemed safe for MRI
# brain scans.

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %% [markdown]
# ## Model Architecture
#
# This time we use ResNet-50 as transfer learning model which loaded with imagenet weight. we freeze the base model early layers and train the later layers of the model. Each block after transfer learning block is followed by Batch Normalization and Dropout.

# %%
def build_resnet50(input_shape=(224, 224, 3), num_classes=4):
    # Load ResNet50 with pretrained ImageNet weights
    base_model = ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )

    # Freeze early layers and unfreeze later layers for fine-tuning
    for layer in base_model.layers[:-30]:
        layer.trainable = False
    for layer in base_model.layers[-30:]:
        layer.trainable = True

    # Build model with ResNet50 base
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

# %%
model = build_resnet50(
    input_shape=X_train.shape[1:],
    num_classes=config['num_classes']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## Training Process
#
# The model is trained for 100 epochs using the Adam optimizer. We monitor validation accuracy
# to save the best weights and reduce the learning rate when the loss plateaus.

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

# %%
callbacks = [
    ModelCheckpoint(filepath=f'{OUTPUT_PATH}/models/best_model.h5', monitor='val_accuracy', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7)
]

# %%
history = model.fit(
    train_datagen.flow(X_train, y_train_cat, batch_size=32),
    epochs=100,
    validation_data=(X_val, y_val_cat),
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.4596 - loss: 1.6115 - precision: 0.4813 - recall: 0.3937
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 111s 554ms/step - accuracy: 0.4599 - loss: 1.6099 - precision: 0.4817 - recall: 0.3939 - val_accuracy: 0.3232 - val_loss: 3.1414 - val_precision: 0.3198 - val_recall: 0.3127 - learning_rate: 0.0010
# Epoch 2/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.5745 - loss: 1.0594 - precision: 0.6329 - recall: 0.4962
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 64s 418ms/step - accuracy: 0.5746 - loss: 1.0592 - precision: 0.6330 - recall: 0.4962 - val_accuracy: 0.6068 - val_loss: 0.9740 - val_precision: 0.7664 - val_recall: 0.4364 - learning_rate: 0.0010
# Epoch 3/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 415ms/step - accuracy: 0.6145 - loss: 0.9440 - precision: 0.6756 - recall: 0.5287 - val_accuracy: 0.5286 - val_loss: 1.2055 - val_precision: 0.5644 - val_recall: 0.4807 - learning_rate: 0.0010
# Epoch 4/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.6354 - loss: 0.8827 - precision: 0.6965 - recall: 0.5445 - val_accuracy: 0.5088 - val_loss: 1.4430 - val_precision: 0.5132 - val_recall: 0.5006 - learning_rate: 0.0010
# Epoch 5/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 409ms/step - accuracy: 0.6521 - loss: 0.8376 - precision: 0.7219 - recall: 0.5679 - val_accuracy: 0.5368 - val_loss: 1.1946 - val_precision: 0.5635 - val_recall: 0.4866 - learning_rate: 0.0010
# Epoch 6/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.6636 - loss: 0.8105 - precision: 0.7283 - recall: 0.5719 - val_accuracy: 0.5484 - val_loss: 1.1656 - val_precision: 0.5707 - val_recall: 0.5041 - learning_rate: 0.0010
# Epoch 7/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 405ms/step - accuracy: 0.6753 - loss: 0.7926 - precision: 0.7404 - recall: 0.5964 - val_accuracy: 0.4924 - val_loss: 1.3213 - val_precision: 0.5614 - val_recall: 0.4481 - learning_rate: 0.0010
# Epoch 8/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.6726 - loss: 0.7867 - precision: 0.7296 - recall: 0.5982
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 64s 418ms/step - accuracy: 0.6727 - loss: 0.7865 - precision: 0.7297 - recall: 0.5983 - val_accuracy: 0.6476 - val_loss: 0.8895 - val_precision: 0.6773 - val_recall: 0.6196 - learning_rate: 0.0010
# Epoch 9/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 405ms/step - accuracy: 0.7011 - loss: 0.7618 - precision: 0.7487 - recall: 0.6246 - val_accuracy: 0.4586 - val_loss: 2.5716 - val_precision: 0.4589 - val_recall: 0.4434 - learning_rate: 0.0010
# Epoch 10/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 407ms/step - accuracy: 0.6912 - loss: 0.7592 - precision: 0.7505 - recall: 0.6089 - val_accuracy: 0.6231 - val_loss: 0.9674 - val_precision: 0.6305 - val_recall: 0.5636 - learning_rate: 0.0010
# Epoch 11/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.6970 - loss: 0.7254 - precision: 0.7541 - recall: 0.6339 - val_accuracy: 0.5321 - val_loss: 1.0721 - val_precision: 0.5902 - val_recall: 0.4924 - learning_rate: 0.0010
# Epoch 12/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.7089 - loss: 0.6967 - precision: 0.7639 - recall: 0.6467
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.7088 - loss: 0.6969 - precision: 0.7638 - recall: 0.6466 - val_accuracy: 0.7270 - val_loss: 0.7045 - val_precision: 0.7525 - val_recall: 0.6919 - learning_rate: 0.0010
# Epoch 13/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 404ms/step - accuracy: 0.7110 - loss: 0.7194 - precision: 0.7632 - recall: 0.6386 - val_accuracy: 0.2905 - val_loss: 3.6443 - val_precision: 0.2886 - val_recall: 0.2859 - learning_rate: 0.0010
# Epoch 14/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 399ms/step - accuracy: 0.7131 - loss: 0.7291 - precision: 0.7624 - recall: 0.6441 - val_accuracy: 0.6091 - val_loss: 1.0903 - val_precision: 0.6124 - val_recall: 0.5881 - learning_rate: 0.0010
# Epoch 15/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 414ms/step - accuracy: 0.7047 - loss: 0.7040 - precision: 0.7567 - recall: 0.6514 - val_accuracy: 0.6593 - val_loss: 0.8301 - val_precision: 0.7242 - val_recall: 0.6068 - learning_rate: 0.0010
# Epoch 16/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 403ms/step - accuracy: 0.7174 - loss: 0.7195 - precision: 0.7713 - recall: 0.6464 - val_accuracy: 0.5263 - val_loss: 1.4690 - val_precision: 0.5345 - val_recall: 0.5158 - learning_rate: 0.0010
# Epoch 17/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.7191 - loss: 0.6916 - precision: 0.7751 - recall: 0.6602
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 410ms/step - accuracy: 0.7190 - loss: 0.6918 - precision: 0.7750 - recall: 0.6601 - val_accuracy: 0.7981 - val_loss: 0.5162 - val_precision: 0.8230 - val_recall: 0.7596 - learning_rate: 0.0010
# Epoch 18/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 410ms/step - accuracy: 0.7171 - loss: 0.6911 - precision: 0.7670 - recall: 0.6542 - val_accuracy: 0.6313 - val_loss: 1.1180 - val_precision: 0.6710 - val_recall: 0.6044 - learning_rate: 0.0010
# Epoch 19/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 401ms/step - accuracy: 0.7161 - loss: 0.6871 - precision: 0.7631 - recall: 0.6489 - val_accuracy: 0.4212 - val_loss: 3.8889 - val_precision: 0.4197 - val_recall: 0.4177 - learning_rate: 0.0010
# Epoch 20/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 409ms/step - accuracy: 0.7150 - loss: 0.7043 - precision: 0.7602 - recall: 0.6578 - val_accuracy: 0.6593 - val_loss: 0.7632 - val_precision: 0.7017 - val_recall: 0.5846 - learning_rate: 0.0010
# Epoch 21/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7234 - loss: 0.6757 - precision: 0.7729 - recall: 0.6637 - val_accuracy: 0.3582 - val_loss: 5.4767 - val_precision: 0.3597 - val_recall: 0.3559 - learning_rate: 0.0010
# Epoch 22/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 404ms/step - accuracy: 0.7130 - loss: 0.6907 - precision: 0.7609 - recall: 0.6452 - val_accuracy: 0.6616 - val_loss: 0.7531 - val_precision: 0.6853 - val_recall: 0.6149 - learning_rate: 0.0010
# Epoch 23/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 398ms/step - accuracy: 0.7298 - loss: 0.6904 - precision: 0.7816 - recall: 0.6625 - val_accuracy: 0.5006 - val_loss: 1.6764 - val_precision: 0.5054 - val_recall: 0.4901 - learning_rate: 0.0010
# Epoch 24/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 398ms/step - accuracy: 0.7345 - loss: 0.6497 - precision: 0.7830 - recall: 0.6748 - val_accuracy: 0.2812 - val_loss: 6.2214 - val_precision: 0.2812 - val_recall: 0.2812 - learning_rate: 0.0010
# Epoch 25/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.7315 - loss: 0.6660 - precision: 0.7646 - recall: 0.6706 - val_accuracy: 0.6838 - val_loss: 0.7954 - val_precision: 0.7222 - val_recall: 0.6068 - learning_rate: 5.0000e-04
# Epoch 26/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.7610 - loss: 0.6124 - precision: 0.7964 - recall: 0.6986
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7609 - loss: 0.6126 - precision: 0.7963 - recall: 0.6985 - val_accuracy: 0.8261 - val_loss: 0.4862 - val_precision: 0.8635 - val_recall: 0.7748 - learning_rate: 5.0000e-04
# Epoch 27/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.7393 - loss: 0.6537 - precision: 0.7757 - recall: 0.6865 - val_accuracy: 0.5613 - val_loss: 1.4285 - val_precision: 0.5896 - val_recall: 0.5146 - learning_rate: 5.0000e-04
# Epoch 28/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.7422 - loss: 0.6549 - precision: 0.7759 - recall: 0.6870 - val_accuracy: 0.7410 - val_loss: 0.6483 - val_precision: 0.7865 - val_recall: 0.6791 - learning_rate: 5.0000e-04
# Epoch 29/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.7392 - loss: 0.6445 - precision: 0.7816 - recall: 0.6878 - val_accuracy: 0.8250 - val_loss: 0.4369 - val_precision: 0.8532 - val_recall: 0.7935 - learning_rate: 5.0000e-04
# Epoch 30/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.7545 - loss: 0.6177 - precision: 0.7823 - recall: 0.7067 - val_accuracy: 0.7001 - val_loss: 0.6860 - val_precision: 0.7674 - val_recall: 0.6546 - learning_rate: 5.0000e-04
# Epoch 31/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 403ms/step - accuracy: 0.7601 - loss: 0.6094 - precision: 0.7995 - recall: 0.7211 - val_accuracy: 0.5986 - val_loss: 1.4871 - val_precision: 0.6173 - val_recall: 0.5834 - learning_rate: 5.0000e-04
# Epoch 32/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.7588 - loss: 0.6240 - precision: 0.7933 - recall: 0.7013 - val_accuracy: 0.5111 - val_loss: 2.5069 - val_precision: 0.5136 - val_recall: 0.5076 - learning_rate: 5.0000e-04
# Epoch 33/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 401ms/step - accuracy: 0.7530 - loss: 0.6201 - precision: 0.7870 - recall: 0.7005 - val_accuracy: 0.8191 - val_loss: 0.4773 - val_precision: 0.8562 - val_recall: 0.7783 - learning_rate: 5.0000e-04
# Epoch 34/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.7561 - loss: 0.6137 - precision: 0.7939 - recall: 0.7069 - val_accuracy: 0.6791 - val_loss: 1.0904 - val_precision: 0.6920 - val_recall: 0.6686 - learning_rate: 5.0000e-04
# Epoch 35/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7545 - loss: 0.6134 - precision: 0.7916 - recall: 0.7053 - val_accuracy: 0.4714 - val_loss: 1.3523 - val_precision: 0.5190 - val_recall: 0.4294 - learning_rate: 5.0000e-04
# Epoch 36/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.7539 - loss: 0.6192 - precision: 0.7871 - recall: 0.7072 - val_accuracy: 0.6149 - val_loss: 1.1738 - val_precision: 0.6519 - val_recall: 0.5683 - learning_rate: 5.0000e-04
# Epoch 37/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7644 - loss: 0.5935 - precision: 0.8037 - recall: 0.7157 - val_accuracy: 0.7585 - val_loss: 0.6211 - val_precision: 0.7854 - val_recall: 0.7305 - learning_rate: 2.5000e-04
# Epoch 38/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 398ms/step - accuracy: 0.7811 - loss: 0.5768 - precision: 0.8158 - recall: 0.7364 - val_accuracy: 0.6348 - val_loss: 1.0499 - val_precision: 0.6484 - val_recall: 0.6219 - learning_rate: 2.5000e-04
# Epoch 39/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.7619 - loss: 0.5851 - precision: 0.7961 - recall: 0.7208 - val_accuracy: 0.7643 - val_loss: 0.6375 - val_precision: 0.7965 - val_recall: 0.7351 - learning_rate: 2.5000e-04
# Epoch 40/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 399ms/step - accuracy: 0.7718 - loss: 0.5879 - precision: 0.8034 - recall: 0.7307 - val_accuracy: 0.7083 - val_loss: 0.6896 - val_precision: 0.7573 - val_recall: 0.6663 - learning_rate: 2.5000e-04
# Epoch 41/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.7728 - loss: 0.5826 - precision: 0.8103 - recall: 0.7325 - val_accuracy: 0.5181 - val_loss: 1.8620 - val_precision: 0.5237 - val_recall: 0.5158 - learning_rate: 2.5000e-04
# Epoch 42/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 401ms/step - accuracy: 0.7785 - loss: 0.5739 - precision: 0.8124 - recall: 0.7381 - val_accuracy: 0.6266 - val_loss: 1.0757 - val_precision: 0.6373 - val_recall: 0.6173 - learning_rate: 2.5000e-04
# Epoch 43/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.7810 - loss: 0.5684 - precision: 0.8101 - recall: 0.7501 - val_accuracy: 0.7631 - val_loss: 0.5739 - val_precision: 0.8026 - val_recall: 0.7165 - learning_rate: 2.5000e-04
# Epoch 44/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.7676 - loss: 0.5935 - precision: 0.7968 - recall: 0.7248 - val_accuracy: 0.7025 - val_loss: 0.6730 - val_precision: 0.7436 - val_recall: 0.6464 - learning_rate: 1.2500e-04
# Epoch 45/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 393ms/step - accuracy: 0.7815 - loss: 0.5514 - precision: 0.8112 - recall: 0.7458 - val_accuracy: 0.7725 - val_loss: 0.5799 - val_precision: 0.8352 - val_recall: 0.6861 - learning_rate: 1.2500e-04
# Epoch 46/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.7812 - loss: 0.5569 - precision: 0.8041 - recall: 0.7370 - val_accuracy: 0.7935 - val_loss: 0.5330 - val_precision: 0.8195 - val_recall: 0.7736 - learning_rate: 1.2500e-04
# Epoch 47/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.7853 - loss: 0.5315 - precision: 0.8170 - recall: 0.7513 - val_accuracy: 0.7631 - val_loss: 0.6443 - val_precision: 0.7904 - val_recall: 0.7480 - learning_rate: 1.2500e-04
# Epoch 48/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.7936 - loss: 0.5069 - precision: 0.8237 - recall: 0.7600 - val_accuracy: 0.6803 - val_loss: 0.8980 - val_precision: 0.7039 - val_recall: 0.6546 - learning_rate: 1.2500e-04
# Epoch 49/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.7943 - loss: 0.5204 - precision: 0.8189 - recall: 0.7626 - val_accuracy: 0.6709 - val_loss: 0.7775 - val_precision: 0.7031 - val_recall: 0.6301 - learning_rate: 1.2500e-04
# Epoch 50/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 401ms/step - accuracy: 0.7759 - loss: 0.5410 - precision: 0.8061 - recall: 0.7426 - val_accuracy: 0.6954 - val_loss: 0.6391 - val_precision: 0.7387 - val_recall: 0.6464 - learning_rate: 1.2500e-04
# Epoch 51/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 393ms/step - accuracy: 0.7848 - loss: 0.5212 - precision: 0.8100 - recall: 0.7523 - val_accuracy: 0.8191 - val_loss: 0.4662 - val_precision: 0.8467 - val_recall: 0.7865 - learning_rate: 6.2500e-05
# Epoch 52/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 403ms/step - accuracy: 0.7836 - loss: 0.5423 - precision: 0.8153 - recall: 0.7491 - val_accuracy: 0.7911 - val_loss: 0.5280 - val_precision: 0.8142 - val_recall: 0.7771 - learning_rate: 6.2500e-05
# Epoch 53/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.7970 - loss: 0.5196 - precision: 0.8294 - recall: 0.7594 - val_accuracy: 0.7468 - val_loss: 0.6366 - val_precision: 0.7728 - val_recall: 0.7223 - learning_rate: 6.2500e-05
# Epoch 54/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.7991 - loss: 0.5119 - precision: 0.8291 - recall: 0.7647
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7990 - loss: 0.5120 - precision: 0.8290 - recall: 0.7647 - val_accuracy: 0.8273 - val_loss: 0.4370 - val_precision: 0.8542 - val_recall: 0.7865 - learning_rate: 6.2500e-05
# Epoch 55/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7931 - loss: 0.5163 - precision: 0.8251 - recall: 0.7562 - val_accuracy: 0.8063 - val_loss: 0.4570 - val_precision: 0.8319 - val_recall: 0.7911 - learning_rate: 6.2500e-05
# Epoch 56/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.7948 - loss: 0.5355 - precision: 0.8209 - recall: 0.7585
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.7948 - loss: 0.5355 - precision: 0.8208 - recall: 0.7585 - val_accuracy: 0.8576 - val_loss: 0.3717 - val_precision: 0.8762 - val_recall: 0.8343 - learning_rate: 6.2500e-05
# Epoch 57/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 403ms/step - accuracy: 0.7958 - loss: 0.5143 - precision: 0.8206 - recall: 0.7564 - val_accuracy: 0.7468 - val_loss: 0.6472 - val_precision: 0.7620 - val_recall: 0.7211 - learning_rate: 6.2500e-05
# Epoch 58/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 393ms/step - accuracy: 0.8091 - loss: 0.5071 - precision: 0.8317 - recall: 0.7742 - val_accuracy: 0.8191 - val_loss: 0.4756 - val_precision: 0.8454 - val_recall: 0.7783 - learning_rate: 6.2500e-05
# Epoch 59/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.7909 - loss: 0.5216 - precision: 0.8209 - recall: 0.7576
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 408ms/step - accuracy: 0.7909 - loss: 0.5216 - precision: 0.8209 - recall: 0.7576 - val_accuracy: 0.8635 - val_loss: 0.3637 - val_precision: 0.8780 - val_recall: 0.8401 - learning_rate: 6.2500e-05
# Epoch 60/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.7784 - loss: 0.5512 - precision: 0.8103 - recall: 0.7437 - val_accuracy: 0.8308 - val_loss: 0.4548 - val_precision: 0.8470 - val_recall: 0.8075 - learning_rate: 6.2500e-05
# Epoch 61/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 398ms/step - accuracy: 0.8053 - loss: 0.5059 - precision: 0.8369 - recall: 0.7661 - val_accuracy: 0.8331 - val_loss: 0.4157 - val_precision: 0.8601 - val_recall: 0.8110 - learning_rate: 6.2500e-05
# Epoch 62/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.7961 - loss: 0.5123 - precision: 0.8218 - recall: 0.7577 - val_accuracy: 0.8133 - val_loss: 0.4659 - val_precision: 0.8252 - val_recall: 0.7876 - learning_rate: 6.2500e-05
# Epoch 63/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 397ms/step - accuracy: 0.7940 - loss: 0.5281 - precision: 0.8223 - recall: 0.7644 - val_accuracy: 0.8366 - val_loss: 0.4419 - val_precision: 0.8513 - val_recall: 0.8215 - learning_rate: 6.2500e-05
# Epoch 64/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.7985 - loss: 0.5143 - precision: 0.8259 - recall: 0.7683 - val_accuracy: 0.7935 - val_loss: 0.5512 - val_precision: 0.8049 - val_recall: 0.7701 - learning_rate: 6.2500e-05
# Epoch 65/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 397ms/step - accuracy: 0.7959 - loss: 0.5155 - precision: 0.8238 - recall: 0.7624 - val_accuracy: 0.7410 - val_loss: 0.6659 - val_precision: 0.7827 - val_recall: 0.6978 - learning_rate: 6.2500e-05
# Epoch 66/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.8054 - loss: 0.5048 - precision: 0.8310 - recall: 0.7686 - val_accuracy: 0.8086 - val_loss: 0.5204 - val_precision: 0.8317 - val_recall: 0.7841 - learning_rate: 6.2500e-05
# Epoch 67/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.7952 - loss: 0.4989 - precision: 0.8205 - recall: 0.7618 - val_accuracy: 0.8378 - val_loss: 0.4255 - val_precision: 0.8528 - val_recall: 0.8250 - learning_rate: 3.1250e-05
# Epoch 68/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.8087 - loss: 0.4882 - precision: 0.8320 - recall: 0.7746 - val_accuracy: 0.8180 - val_loss: 0.4573 - val_precision: 0.8319 - val_recall: 0.8028 - learning_rate: 3.1250e-05
# Epoch 69/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 397ms/step - accuracy: 0.7985 - loss: 0.4911 - precision: 0.8233 - recall: 0.7692 - val_accuracy: 0.8320 - val_loss: 0.4213 - val_precision: 0.8639 - val_recall: 0.8075 - learning_rate: 3.1250e-05
# Epoch 70/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.8056 - loss: 0.5051 - precision: 0.8355 - recall: 0.7716 - val_accuracy: 0.8366 - val_loss: 0.4116 - val_precision: 0.8585 - val_recall: 0.8145 - learning_rate: 3.1250e-05
# Epoch 71/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.7964 - loss: 0.5107 - precision: 0.8242 - recall: 0.7588 - val_accuracy: 0.8355 - val_loss: 0.4423 - val_precision: 0.8549 - val_recall: 0.8110 - learning_rate: 3.1250e-05
# Epoch 72/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.8169 - loss: 0.4791 - precision: 0.8407 - recall: 0.7790 - val_accuracy: 0.8086 - val_loss: 0.4759 - val_precision: 0.8298 - val_recall: 0.7795 - learning_rate: 3.1250e-05
# Epoch 73/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.8056 - loss: 0.5045 - precision: 0.8270 - recall: 0.7759 - val_accuracy: 0.8390 - val_loss: 0.4135 - val_precision: 0.8573 - val_recall: 0.8203 - learning_rate: 3.1250e-05
# Epoch 74/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.8025 - loss: 0.4977 - precision: 0.8259 - recall: 0.7720 - val_accuracy: 0.8401 - val_loss: 0.4110 - val_precision: 0.8608 - val_recall: 0.8226 - learning_rate: 1.5625e-05
# Epoch 75/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.8174 - loss: 0.4730 - precision: 0.8387 - recall: 0.7810 - val_accuracy: 0.8250 - val_loss: 0.4405 - val_precision: 0.8429 - val_recall: 0.8075 - learning_rate: 1.5625e-05
# Epoch 76/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 409ms/step - accuracy: 0.8056 - loss: 0.4821 - precision: 0.8300 - recall: 0.7734 - val_accuracy: 0.8051 - val_loss: 0.4911 - val_precision: 0.8210 - val_recall: 0.7865 - learning_rate: 1.5625e-05
# Epoch 77/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.8108 - loss: 0.4826 - precision: 0.8392 - recall: 0.7812 - val_accuracy: 0.8471 - val_loss: 0.3982 - val_precision: 0.8616 - val_recall: 0.8355 - learning_rate: 1.5625e-05
# Epoch 78/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.8222 - loss: 0.4862 - precision: 0.8377 - recall: 0.7865 - val_accuracy: 0.8530 - val_loss: 0.3866 - val_precision: 0.8627 - val_recall: 0.8355 - learning_rate: 1.5625e-05
# Epoch 79/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.8074 - loss: 0.4814 - precision: 0.8379 - recall: 0.7811 - val_accuracy: 0.8425 - val_loss: 0.4037 - val_precision: 0.8641 - val_recall: 0.8238 - learning_rate: 1.5625e-05
# Epoch 80/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.8095 - loss: 0.4753 - precision: 0.8355 - recall: 0.7808 - val_accuracy: 0.8495 - val_loss: 0.3909 - val_precision: 0.8622 - val_recall: 0.8320 - learning_rate: 1.5625e-05
# Epoch 81/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 395ms/step - accuracy: 0.8017 - loss: 0.4883 - precision: 0.8278 - recall: 0.7740 - val_accuracy: 0.8296 - val_loss: 0.4235 - val_precision: 0.8505 - val_recall: 0.8168 - learning_rate: 7.8125e-06
# Epoch 82/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.8070 - loss: 0.4965 - precision: 0.8297 - recall: 0.7766 - val_accuracy: 0.8203 - val_loss: 0.4426 - val_precision: 0.8350 - val_recall: 0.8028 - learning_rate: 7.8125e-06
# Epoch 83/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.8134 - loss: 0.4696 - precision: 0.8371 - recall: 0.7797 - val_accuracy: 0.8308 - val_loss: 0.4200 - val_precision: 0.8487 - val_recall: 0.8180 - learning_rate: 7.8125e-06
# Epoch 84/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 407ms/step - accuracy: 0.8046 - loss: 0.4770 - precision: 0.8373 - recall: 0.7783 - val_accuracy: 0.8355 - val_loss: 0.4117 - val_precision: 0.8530 - val_recall: 0.8191 - learning_rate: 7.8125e-06
# Epoch 85/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 405ms/step - accuracy: 0.8126 - loss: 0.4820 - precision: 0.8371 - recall: 0.7762 - val_accuracy: 0.8413 - val_loss: 0.3966 - val_precision: 0.8646 - val_recall: 0.8273 - learning_rate: 7.8125e-06
# Epoch 86/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.8144 - loss: 0.4849 - precision: 0.8359 - recall: 0.7886 - val_accuracy: 0.8308 - val_loss: 0.4245 - val_precision: 0.8501 - val_recall: 0.8203 - learning_rate: 7.8125e-06
# Epoch 87/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 404ms/step - accuracy: 0.7985 - loss: 0.5030 - precision: 0.8224 - recall: 0.7760 - val_accuracy: 0.8250 - val_loss: 0.4345 - val_precision: 0.8437 - val_recall: 0.8063 - learning_rate: 7.8125e-06
# Epoch 88/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 396ms/step - accuracy: 0.8073 - loss: 0.4833 - precision: 0.8362 - recall: 0.7745 - val_accuracy: 0.8355 - val_loss: 0.4169 - val_precision: 0.8542 - val_recall: 0.8203 - learning_rate: 3.9063e-06
# Epoch 89/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 417ms/step - accuracy: 0.8144 - loss: 0.4825 - precision: 0.8342 - recall: 0.7858 - val_accuracy: 0.8401 - val_loss: 0.4063 - val_precision: 0.8561 - val_recall: 0.8261 - learning_rate: 3.9063e-06
# Epoch 90/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 413ms/step - accuracy: 0.8197 - loss: 0.4767 - precision: 0.8395 - recall: 0.7890 - val_accuracy: 0.8390 - val_loss: 0.4063 - val_precision: 0.8598 - val_recall: 0.8226 - learning_rate: 3.9063e-06
# Epoch 91/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.8183 - loss: 0.4709 - precision: 0.8452 - recall: 0.7847 - val_accuracy: 0.8401 - val_loss: 0.4106 - val_precision: 0.8558 - val_recall: 0.8238 - learning_rate: 3.9063e-06
# Epoch 92/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 410ms/step - accuracy: 0.8118 - loss: 0.4889 - precision: 0.8337 - recall: 0.7787 - val_accuracy: 0.8390 - val_loss: 0.4106 - val_precision: 0.8575 - val_recall: 0.8285 - learning_rate: 3.9063e-06
# Epoch 93/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 403ms/step - accuracy: 0.8057 - loss: 0.5065 - precision: 0.8237 - recall: 0.7758 - val_accuracy: 0.8413 - val_loss: 0.4007 - val_precision: 0.8575 - val_recall: 0.8285 - learning_rate: 3.9063e-06
# Epoch 94/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 63s 411ms/step - accuracy: 0.8002 - loss: 0.5060 - precision: 0.8238 - recall: 0.7720 - val_accuracy: 0.8413 - val_loss: 0.4095 - val_precision: 0.8527 - val_recall: 0.8238 - learning_rate: 3.9063e-06
# Epoch 95/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 405ms/step - accuracy: 0.8122 - loss: 0.4717 - precision: 0.8386 - recall: 0.7833 - val_accuracy: 0.8425 - val_loss: 0.3972 - val_precision: 0.8568 - val_recall: 0.8308 - learning_rate: 1.9531e-06
# Epoch 96/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.8041 - loss: 0.4867 - precision: 0.8330 - recall: 0.7722 - val_accuracy: 0.8401 - val_loss: 0.4073 - val_precision: 0.8540 - val_recall: 0.8261 - learning_rate: 1.9531e-06
# Epoch 97/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.8057 - loss: 0.4974 - precision: 0.8290 - recall: 0.7794 - val_accuracy: 0.8425 - val_loss: 0.4027 - val_precision: 0.8563 - val_recall: 0.8273 - learning_rate: 1.9531e-06
# Epoch 98/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 398ms/step - accuracy: 0.7983 - loss: 0.4989 - precision: 0.8272 - recall: 0.7708 - val_accuracy: 0.8413 - val_loss: 0.4078 - val_precision: 0.8584 - val_recall: 0.8273 - learning_rate: 1.9531e-06
# Epoch 99/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.8238 - loss: 0.4572 - precision: 0.8481 - recall: 0.7937 - val_accuracy: 0.8366 - val_loss: 0.4140 - val_precision: 0.8547 - val_recall: 0.8238 - learning_rate: 1.9531e-06
# Epoch 100/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 60s 397ms/step - accuracy: 0.8044 - loss: 0.4813 - precision: 0.8255 - recall: 0.7771 - val_accuracy: 0.8425 - val_loss: 0.4006 - val_precision: 0.8587 - val_recall: 0.8296 - learning_rate: 1.9531e-06

# %%
MODEL_NAME = 'resnet50'

# %%
history_path = f'{OUTPUT_PATH}/histories/{MODEL_NAME}_history.npy'
np.save(history_path, history.history)

# %%
final_model_path = f'{OUTPUT_PATH}/models/{MODEL_NAME}_final.h5'
model.save(final_model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
best_model = keras.models.load_model(f'{OUTPUT_PATH}/models/{MODEL_NAME}_final.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Test Time Augmentation (TTA)
#
# TTA is utilized during the inference phase. By generating 10 augmented versions of each test
# image and averaging the predictions, we significantly increase the robustness of the final classification.

# %%
def predict_with_tta(model, X, n_augmentations=10):
    predictions = []
    preds = model.predict(X, verbose=0)
    predictions.append(preds)
    tta_gen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True
    )
    for i in range(n_augmentations):
        aug_iterator = tta_gen.flow(X, batch_size=len(X), shuffle=False)
        X_aug = next(iter(aug_iterator))
        preds_aug = model.predict(X_aug, verbose=0)
        predictions.append(preds_aug)
    return np.mean(predictions, axis=0)

test_preds_tta = predict_with_tta(best_model, X_test, n_augmentations=10)
test_acc_tta = np.mean(np.argmax(test_preds_tta, axis=1) == np.argmax(y_test_cat, axis=1))

print(f"\nTTA completed!")

# EVALUATION

print("\n")
print("EVALUATION")

# Validation
val_results = best_model.evaluate(X_val, y_val_cat, verbose=0)
print(f"\nValidation Results (Best Model):")
print(f"Loss: {val_results[0]:.4f}")
print(f"Accuracy: {val_results[1]*100:.2f}%")
print(f"Precision: {val_results[2]:.4f}")
print(f"Recall: {val_results[3]:.4f}")

# Test (standard)
test_results = best_model.evaluate(X_test, y_test_cat, verbose=0)
print(f"\nTest Results (Standard):")
print(f"Loss: {test_results[0]:.4f}")
print(f"Accuracy: {test_results[1]*100:.2f}%")
print(f"Precision: {test_results[2]:.4f}")
print(f"Recall: {test_results[3]:.4f}")

# Test (with TTA)
print(f"\nTest Results (With TTA):")
print(f"Accuracy: {test_acc_tta*100:.2f}%")

print("\nSUMMARY:")
print(f"Baseline Test Acc: 93.82%")
print(f"Test Acc (Standard): {test_results[1]*100:.2f}%")
print(f"Test Acc (TTA): {test_acc_tta*100:.2f}%")
# Out:
# TTA completed!
#
#
# EVALUATION
#
# Validation Results (Best Model):
# Loss: 0.4006
# Accuracy: 84.25%
# Precision: 0.8587
# Recall: 0.8296
#
# Test Results (Standard):
# Loss: 0.5175
# Accuracy: 79.71%
# Precision: 0.8175
# Recall: 0.7788
#
# Test Results (With TTA):
# Accuracy: 82.99%
#
# SUMMARY:
# Baseline Test Acc: 93.82%
# Test Acc (Standard): 79.71%
# Test Acc (TTA): 82.99%
